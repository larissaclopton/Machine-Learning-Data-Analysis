# %%
# TODO
# finish word responses

# %%
from pyspark.sql import SparkSession
from pyspark.mllib.clustering import KMeans
from IPython.display import clear_output
from collections import Counter
from operator import add
import json
import numpy as np
import string
import matplotlib.pyplot as plt

spark  = SparkSession.builder.appName("SOU").getOrCreate()
speeches = spark.read.json("/project/cmsc25025/sou/speeches.json")
speeches = speeches.sort("year",ascending=True) # sort by year for easier processing

# counts all words across all speeches
word_counts = speeches.rdd.map(lambda x: Counter(x['text'].lower().encode('utf-8').translate(string.maketrans("",""), string.punctuation).split())).reduce(lambda a, b: a+b)
speech = speeches.rdd.map(lambda x: [[str(x['president']), int(x['year'])]]).reduce(lambda a, b: a+b)

# %%
# remove the most/least common words from the counter
# throw out 20 most common words and words that appear less than 50 times
common = word_counts.most_common() # orders words in the counter by most common
for w,c in common[:20] + common[3170:]:
    del word_counts[w] # be careful with this, will continue to delete elements if don't rerun
# extract the remaining words to build a vocabulary
vocab = [wc[0] for wc in word_counts.items()]

ndocuments = speeches.rdd.count() # total number of documents

# count number of times each word appears in each document
vocab_counts = speeches.rdd.map(lambda x: ([[x['text'].lower().encode('utf-8').translate(string.maketrans("",""), string.punctuation).count(i) for i in vocab]])).reduce(lambda a, b: a+b)

# count number of documents each word appears in
doc_counts = speeches.rdd.map(lambda x: ([int(i in x['text'].lower().encode('utf-8').translate(string.maketrans("",""), string.punctuation)) for i in vocab])).reduce(lambda a, b: map(add, a, b))

# compute TF-IDF weights for each SOU address
def computeTF_IDF(counts):
    return np.multiply(counts,log_factor)

log_factor = np.log(np.divide(np.repeat(ndocuments,len(vocab)),np.array(doc_counts)))
TF_IDF = np.apply_along_axis(computeTF_IDF, 1, np.array(vocab_counts))

# %%
# define and fill a lower triangular similarity matrix
sim_matrix = np.zeros((ndocuments,ndocuments))
norms = np.linalg.norm(TF_IDF,ord=None,axis=1) # the norms for each document's TF-IDF vector
for i in range(ndocuments):
    for j in range(i+1,ndocuments):
        # compute the similarity
        sim_matrix[j,i] = np.dot(TF_IDF[i,:],TF_IDF[j,:])/(norms[i]*norms[j])

# find 50 most similar pairs by different presidents
tmp_sim_matrix = sim_matrix
npairs = 0 # number of pairs found
diff_pairs = []
while npairs < 50:
    # find the indices of current maximum similarity
    i,j = np.unravel_index(tmp_sim_matrix.argmax(), tmp_sim_matrix.shape)
    if speech[i][0] != speech[j][0]: # else - ignore if same president
        # add this pair (presidents and years)
        diff_pairs += [(speech[i][0],speech[i][1],speech[j][0],speech[j][1])]
        npairs += 1    
    # set to 0 so this pair is no longer considered
    tmp_sim_matrix[i,j] = 0
print('The 50 most similar pairs of SOUs by different presidents are')
for pair in diff_pairs:
    print pair
print "\n"
    
# find 50 most similar pairs by same president
tmp_sim_matrix = sim_matrix
npairs = 0 # number of pairs found
same_pairs = []
while npairs < 50:
    # find the indices of current maximum similarity
    i,j = np.unravel_index(tmp_sim_matrix.argmax(), tmp_sim_matrix.shape)
    if speech[i][0] == speech[j][0]: # else - ignore if different presidents
        # add this pair (president and years)
        same_pairs += [(speech[i][0],speech[i][1],speech[j][1])]
        npairs += 1    
    # set to 0 so this pair is no longer considered
    tmp_sim_matrix[i,j] = 0
print('The 50 most similar pairs of SOUs by the same president are')
for pair in same_pairs:
    print pair
print "\n"
    
# find 25 most similar pairs of presidents
names = list(set([row[0] for row in speech])) # unique president names
ii = [np.where(np.array([row[0] for row in speech]) == name)[0] for name in names] # index list for each president

# compute average similarity for all pairs of presidents
pres_pairs = []
for i in range(len(names)):
    for j in range(i+1,len(names)):
        total_sim = 0 # total similarity
        for a in ii[i]:
            for b in ii[j]:
                if a > b:
                    total_sim += sim_matrix[a][b]
                else:
                    total_sim += sim_matrix[b][a]
        avg_sim = total_sim/float(len(ii[i])*len(ii[j])) # average similarity
        pres_pairs += [(avg_sim,names[i],names[j])]
# sort by average similarity
pres_pairs = sorted(pres_pairs, key=lambda x: x[0],reverse=True)[:25]
print('The 25 most similar pairs of presidents are')
for pair in pres_pairs:
    print (pair[1],pair[2])
print "\n"
# Out:
# The 50 most similar pairs of SOUs by different presidents are
# ('Barack Obama', 2010, 'William J. Clinton', 1995)
# ('Barack Obama', 2009, 'William J. Clinton', 1993)
# ('William J. Clinton', 2000, 'George Bush', 1989)
# ('Grover Cleveland', 1885, 'Rutherford B. Hayes', 1877)
# ('James K. Polk', 1846, 'John Tyler', 1844)
# ('Barack Obama', 2011, 'William J. Clinton', 1995)
# ('Barack Obama', 2012, 'William J. Clinton', 1993)
# ('Barack Obama', 2011, 'William J. Clinton', 1993)
# ('Barack Obama', 2011, 'William J. Clinton', 2000)
# ('Barack Obama', 2010, 'William J. Clinton', 1993)
# ('George Bush', 1989, 'Ronald Reagan', 1988)
# ('William J. Clinton', 1997, 'George Bush', 1989)
# ('Barack Obama', 2012, 'William J. Clinton', 1995)
# ('Benjamin Harrison', 1889, 'Grover Cleveland', 1885)
# ('Barack Obama', 2010, 'William J. Clinton', 1994)
# ('Ronald Reagan', 1981, 'Gerald R. Ford', 1975)
# ('Barack Obama', 2009, 'William J. Clinton', 2000)
# ('Barack Obama', 2012, 'William J. Clinton', 1994)
# ('Barack Obama', 2011, 'William J. Clinton', 1998)
# ('Barack Obama', 2009, 'William J. Clinton', 1995)
# ('George Bush', 1989, 'Ronald Reagan', 1986)
# ('Barack Obama', 2013, 'William J. Clinton', 1993)
# ('William J. Clinton', 1995, 'George Bush', 1992)
# ('Barack Obama', 2011, 'William J. Clinton', 1994)
# ('Grover Cleveland', 1885, 'Rutherford B. Hayes', 1880)
# ('William J. Clinton', 1993, 'Ronald Reagan', 1981)
# ('James K. Polk', 1845, 'John Tyler', 1844)
# ('William J. Clinton', 2000, 'George Bush', 1990)
# ('William J. Clinton', 1993, 'George Bush', 1992)
# ('William J. Clinton', 2000, 'Ronald Reagan', 1988)
# ('George W. Bush', 2001, 'William J. Clinton', 2000)
# ('Ronald Reagan', 1982, 'Gerald R. Ford', 1976)
# ('Martin Van Buren', 1839, 'Andrew Jackson', 1836)
# ('Barack Obama', 2011, 'William J. Clinton', 1997)
# ('William J. Clinton', 1994, 'George Bush', 1992)
# ('William J. Clinton', 1998, 'George Bush', 1989)
# ('Barack Obama', 2011, 'Ronald Reagan', 1984)
# ('Barack Obama', 2010, 'William J. Clinton', 2000)
# ('William Howard Taft', 1910, 'Theodore Roosevelt', 1907)
# ('Barack Obama', 2011, 'George Bush', 1992)
# ('Ronald Reagan', 1982, 'Gerald R. Ford', 1975)
# ('William J. Clinton', 2000, 'Ronald Reagan', 1985)
# ('George W. Bush', 2001, 'William J. Clinton', 1997)
# ('Barack Obama', 2009, 'William J. Clinton', 1997)
# ('Barack Obama', 2010, 'William J. Clinton', 1998)
# ('Barack Obama', 2009, 'William J. Clinton', 1994)
# ('George W. Bush', 2001, 'William J. Clinton', 1999)
# ('William J. Clinton', 1994, 'George Bush', 1989)
# ('William J. Clinton', 1997, 'Ronald Reagan', 1988)
# ('Barack Obama', 2009, 'William J. Clinton', 1998)
#
#
# The 50 most similar pairs of SOUs by the same president are
# ('Benjamin Harrison', 1892, 1891)
# ('Chester A. Arthur', 1883, 1881)
# ('Theodore Roosevelt', 1907, 1902)
# ('Dwight D. Eisenhower', 1954, 1953)
# ('Chester A. Arthur', 1883, 1882)
# ('William J. Clinton', 1999, 1995)
# ('George W. Bush', 2005, 2002)
# ('William J. Clinton', 1999, 1994)
# ('Benjamin Harrison', 1891, 1889)
# ('Ronald Reagan', 1988, 1984)
# ('Chester A. Arthur', 1884, 1881)
# ('John Tyler', 1844, 1843)
# ('Chester A. Arthur', 1884, 1882)
# ('Dwight D. Eisenhower', 1959, 1956)
# ('Andrew Jackson', 1830, 1829)
# ('William J. Clinton', 1997, 1993)
# ('Ulysses S. Grant', 1873, 1872)
# ('James Buchanan', 1860, 1857)
# ('Theodore Roosevelt', 1908, 1906)
# ('Benjamin Harrison', 1890, 1889)
# ('George W. Bush', 2006, 2002)
# ('Theodore Roosevelt', 1908, 1905)
# ('James Monroe', 1821, 1819)
# ('Lyndon B. Johnson', 1968, 1967)
# ('Dwight D. Eisenhower', 1961, 1953)
# ('Gerald R. Ford', 1976, 1975)
# ('Rutherford B. Hayes', 1880, 1877)
# ('John F. Kennedy', 1963, 1961)
# ('Ronald Reagan', 1988, 1985)
# ('Millard Fillmore', 1852, 1851)
# ('Harry S Truman', 1950, 1949)
# ('William J. Clinton', 1996, 1993)
# ('Herbert Hoover', 1931, 1930)
# ('George Bush', 1992, 1989)
# ('Martin Van Buren', 1839, 1838)
# ('William Howard Taft', 1911, 1910)
# ('Lyndon B. Johnson', 1969, 1968)
# ('Calvin Coolidge', 1927, 1926)
# ('James K. Polk', 1848, 1845)
# ('Dwight D. Eisenhower', 1961, 1959)
# ('George Bush', 1992, 1990)
# ('Franklin Pierce', 1856, 1855)
# ('John Tyler', 1843, 1842)
# ('Rutherford B. Hayes', 1879, 1878)
# ('Millard Fillmore', 1851, 1850)
# ('Harry S Truman', 1948, 1947)
# ('Theodore Roosevelt', 1906, 1901)
# ('Theodore Roosevelt', 1908, 1901)
# ('Ronald Reagan', 1987, 1986)
# ('Ronald Reagan', 1985, 1983)
#
#
# The 25 most similar pairs of presidents are
# ('Zachary Taylor', 'Millard Fillmore')
# ('Gerald R. Ford', 'John F. Kennedy')
# ('Gerald R. Ford', 'Richard M. Nixon')
# ('Millard Fillmore', 'James K. Polk')
# ('John F. Kennedy', 'Dwight D. Eisenhower')
# ('Chester A. Arthur', 'Rutherford B. Hayes')
# ('Benjamin Harrison', 'Chester A. Arthur')
# ('Martin Van Buren', 'John Tyler')
# ('Millard Fillmore', 'Franklin Pierce')
# ('Theodore Roosevelt', 'William Howard Taft')
# ('John F. Kennedy', 'Lyndon B. Johnson')
# ('Chester A. Arthur', 'William Howard Taft')
# ('Gerald R. Ford', 'Dwight D. Eisenhower')
# ('Ronald Reagan', 'Barack Obama')
# ('George Bush', 'Barack Obama')
# ('Gerald R. Ford', 'Jimmy Carter')
# ('Harry S Truman', 'Dwight D. Eisenhower')
# ('Chester A. Arthur', 'Grover Cleveland')
# ('Chester A. Arthur', 'Ulysses S. Grant')
# ('George Bush', 'Gerald R. Ford')
# ('Rutherford B. Hayes', 'Grover Cleveland')
# ('Calvin Coolidge', 'Herbert Hoover')
# ('Millard Fillmore', 'Chester A. Arthur')
# ('Millard Fillmore', 'Ulysses S. Grant')
# ('Calvin Coolidge', 'William Howard Taft')

# %% [markdown]
# The speeches are somewhat similar in their word content but still vary in overall theme/topics. A better similarity measure might be constructed by considering phrases rather than single words. Latent semantic analysis may also be applicable, finding a set of concepts for each documents and comparing these.

# %%
# cluster the TDF-IDF representations using k-means
# experimenting with the number of clusters
TF_IDF_rdd = spark.sparkContext.parallelize(TF_IDF)
years = [row[1] for row in speech]
names = [row[0] for row in speech]
k = [6,8,10,12,14] # number of clusters
for num in k:
    # compute the clusters
    clusters = KMeans.train(TF_IDF_rdd, num, maxIterations=50, initializationMode="random")
    # TODO - display the clusters
    predictions = clusters.predict(TF_IDF_rdd).collect()
    year_cluster = [(names[i],years[i],predictions[i]) for i in range(len(predictions))]
    sorted_clusters = sorted(year_cluster, key=lambda x: x[1])
    print "%d clusters" % num
    for i in range(1,num+1):
        print "cluster %d" % i
        print [(val[0],val[1]) for val in sorted_clusters if val[2] == i]

# TODO - Comment on the clustering results, and whether or not the results are interpretable
# Out:
# 6 clusters
# cluster 1
# [('Harry S Truman', 1946), ('Lyndon B. Johnson', 1966), ('Lyndon B. Johnson', 1967), ('Lyndon B. Johnson', 1968), ('Gerald R. Ford', 1976), ('Ronald Reagan', 1981), ('Ronald Reagan', 1982), ('Ronald Reagan', 1983), ('Ronald Reagan', 1984), ('Ronald Reagan', 1985), ('Ronald Reagan', 1988), ('George Bush', 1989), ('George Bush', 1990), ('George Bush', 1991), ('George Bush', 1992), ('William J. Clinton', 1993), ('William J.
# cluster 8
# [('James K. Polk', 1845), ('James K. Polk', 1846), ('James K. Polk', 1847), ('James K. Polk', 1848), ('Millard Fillmore', 1851), ('Rutherford B. Hayes', 1877), ('Rutherford B. Hayes', 1879), ('Rutherford B. Hayes', 1880), ('Chester A. Arthur', 1881), ('Grover Cleveland', 1885), ('Grover Cleveland', 1886), ('Grover Cleveland', 1888), ('Benjamin Harrison', 1889), ('Benjamin Harrison', 1890), ('Benjamin Harrison', 1891), ('Benjamin Harrison', 1892), ('Grover Cleveland', 1893), ('Grover Cleveland', 1894), ('Grover Cleveland', 1895), ('Grover Cleveland', 1896), ('William McKinley', 1897), ('William McKinley', 1898)]
# cluster 9
# [('Martin Van Buren', 1839)]
# cluster 10
# []
# 12 clusters
# cluster 1
# [('James K. Polk', 1845), ('James K. Polk', 1846), ('James K. Polk', 1847), ('Benjamin Harrison', 1892)]
# cluster 2
# [('William Howard Taft', 1912)]
# cluster 3
# [('William McKinley', 1899), ('William McKinley', 1900)]
# cluster 4
# [('Ronald Reagan', 1984), ('Ronald Reagan', 1988), ('George Bush', 1989), ('William J. Clinton', 1993), ('William J. Clinton', 1994), ('William J. Clinton', 1995), ('William J. Clinton', 1996), ('William J. Clinton', 1997), ('William J. Clinton', 1998), ('William J. Clinton', 1999), ('William J. Clinton', 2000)]
# cluster 5
# [('George Washington', 1790), ('George Washington', 1791), ('George Washington', 1792), ('George Washington', 1793), ('George Washington', 1794), ('George Washington', 1795), ('George Washington', 1796), ('John Adams', 1797), ('John Adams', 1798), ('John Adams', 1799), ('John Adams', 1800), ('Thomas Jefferson', 1801), ('Thomas Jefferson', 1802), ('Thomas Jefferson', 1803), ('Thomas Jefferson', 1804), ('Thomas Jefferson', 1805), ('Thomas Jefferson', 1806), ('Thomas Jefferson', 1807), ('Thomas Jefferson', 1808), ('James Madison', 1809), ('James Madison', 1810), ('James Madison', 1811), ('James Madison', 1812), ('James Madison', 1813), ('James Madison', 1814), ('James Madison', 1815), ('James Madison', 1816), ('James Monroe', 1817), ('James Monroe', 1818), ('James Monroe', 1819), ('James Monroe', 1820), ('James Monroe', 1821), ('James Monroe', 1822), ('James Monroe', 1823), ('James Monroe', 1824), ('John Quincy Adams', 1825), ('John Quincy Adams', 1826), ('John Quincy Adams', 1827), ('John Quincy Adams', 1828), ('Andrew Jackson', 1829), ('Andrew Jackson', 1831), ('Andrew Jackson', 1832), ('Andrew Jackson', 1833), ('Zachary Taylor', 1849), ('Millard Fillmore', 1850), ('Abraham Lincoln', 1861), ('Abraham Lincoln', 1863), ('Abraham Lincoln', 1864), ('Andrew Johnson', 1865), ('Andrew Johnson', 1866), ('Ulysses S. Grant', 1871), ('Ulysses S. Grant', 1876), ('Grover Cleveland', 1887), ('Theodore Roosevelt', 1902), ('Wood
# [('Andrew Jackson', 1830), ('Andrew Jackson', 1834), ('Andrew Jackson', 1835), ('Andrew Jackson', 1836), ('Martin Van Buren', 1837), ('Martin Van Buren', 1838), ('Martin Van Buren', 1839), ('Martin Van Buren', 1840), ('John Tyler', 1841), ('John Tyler', 1842), ('John Tyler', 1843), ('John Tyler', 1844), ('Millard Fillmore', 1851), ('Millard Fillmore', 1852), ('Franklin Pierce', 1853), ('Franklin Pierce', 1854), ('Franklin Pierce', 1855), ('Franklin Pierce', 1856), ('James Buchanan', 1857), ('James Buchanan', 1858), ('James Buchanan', 1859), ('James Buchanan', 1860), ('Abraham Lincoln', 1862), ('Andrew Johnson', 1867), ('Andrew Johnson', 1868), ('Ulysses S. Grant', 1869), ('Ulysses S. Grant', 1870), ('Ulysses S. Grant', 1872), ('Ulysses S. Grant', 1873), ('Ulysses S. Grant', 1874), ('Ulysses S. Grant', 1875), ('Rutherford B. Hayes', 1877), ('Rutherford B. Hayes', 1878), ('Rutherford B. Hayes', 1879), ('Rutherford B. Hayes', 1880), ('Chester A. Arthur', 1881), ('Chester A. Arthur', 1882), ('Chester A. Arthur', 1883), ('Chester A. Arthur', 1884), ('Grover Cleveland', 1885), ('Grover Cleveland', 1886), ('Grover Cleveland', 1888), ('Benjamin Harrison', 1889), ('Benjamin Harrison', 1890), ('Benjamin Harrison', 1891), ('Grover Cleveland', 1893), ('Grover Cleveland', 1894), ('Grover Cleveland', 1895), ('Grover Cleveland', 1896), ('William McKinley', 1897), ('William Howard Taft', 1909)]
# cluster 11
# [('Theodore Roosevelt', 1901), ('Theodore Roosevelt', 1904), ('Theodore Roosevelt', 1905), ('Theodore Roosevelt', 1906), ('Theodore Roosevelt', 1907), ('Theodore Roosevelt', 1908), ('William Howard Taft', 1910), ('William Howard Taft', 1911), ('Harry S Truman', 1946)]
# cluster 12
# []
# 14 clusters
# cluster 1
# [('James K. Polk', 1848), ('Benjamin Harrison', 1891), ('Benjamin Harrison', 1892)]
# cluster 2
# [('James Buchanan', 1857), ('James Buchanan', 1858), ('James Buchanan', 1859), ('James Buchanan', 1860)]
# cluster 3
# [('George Bush', 1989), ('William J. Clinton', 1993), ('William J. Clinton', 1994), ('William J. Clinton', 1995), ('William J. Clinton', 1996), ('William J. Clinton', 1997), ('William J. Clinton', 1998), ('William J. Clinton', 1999), ('William J. Clinton', 2000), ('Barack Obama', 2009), ('Barack Obama', 2010), ('Barack Obama', 2011), ('Barack Obama', 2012), ('Barack Obama', 2013)]
# cluster 4
# [('George W. Bush', 2003), ('George W. Bush', 2004), ('George W. Bush', 2005), ('George W. Bush', 2006), ('George W. Bush', 2007), ('George W. Bush', 2008)]
# cluster 5
# [('Theodore Roosevelt', 1901), ('Theodore Roosevelt', 1904), ('Theodore Roosevelt', 1905), ('Theodore Roosevelt', 1906), ('Theodore Roosevelt', 1907), ('Theodore Roosevelt', 1908), ('William Howard Taft', 1910), ('William Howard Taft', 1911), ('William Howard Taft', 1912)]
# cluster 12
# [('Woodrow Wilson', 1915), ('Woodrow Wilson', 1918), ('Woodrow Wilson', 1919), ('Warren G. Harding', 1921), ('Warren G. Harding', 1922), ('Calvin Coolidge', 1923), ('Calvin Coolidge', 1924), ('Calvin Coolidge', 1925), ('Calvin Coolidge', 1926), ('Calvin Coolidge', 1927), ('Calvin Coolidge', 1928), ('Herbert Hoover', 1929), ('Herbert Hoover', 1930), ('Herbert Hoover', 1931), ('Herbert Hoover', 1932), ('Franklin D. Roosevelt', 1934), ('Franklin D. Roosevelt', 1935), ('Franklin D. Roosevelt', 1936), ('Franklin D. Roosevelt', 1937), ('Franklin D. Roosevelt', 1938), ('Franklin D. Roosevelt', 1939), ('Franklin D. Roosevelt', 1940), ('Franklin D. Roosevelt', 1941), ('Franklin D. Roosevelt', 1942), ('Franklin D. Roosevelt', 1943), ('Franklin D. Roosevelt', 1944), ('Franklin D. Roosevelt', 1945), ('Harry S Truman', 1947), ('Harry S Truman', 1948), ('Harry S Truman', 1949), ('Harry S Truman', 1950), ('Harry S Truman', 1951), ('Harry S Truman', 1952), ('Harry S Truman', 1953), ('Dwight D. Eisenhower', 1953), ('Dwight D. Eisenhower', 1954), ('Dwight D. Eisenhower', 1955), ('Dwight D. Eisenhower', 1956), ('Dwight D. Eisenhower', 1957), ('Dwight D. Eisenhower', 1958), ('Dwight D. Eisenhower', 1959), ('Dwight D. Eisenhower', 1960), ('Dwight D. Eisenhower', 1961), ('John F. Kennedy', 1961), ('John F. Kennedy', 1962), ('John F. Kennedy', 1963), ('Lyndon B. Johnson', 1964), ('Lyndon B. Johnson', 1965), ('Lyndon B. Johnson', 1966), ('Lyndon B. Johnson', 1967), ('Lyndon B. Johnson', 1968), ('Lyndon B. Johnson', 1969), ('Richard M. Nixon', 1970), ('Richard M. Nixon', 1971), ('Richard M. Nixon', 1972), ('Richard M. Nixon', 1973), ('Richard M. Nixon', 1974), ('Gerald R. Ford', 1975), ('Gerald R. Ford', 1976), ('Gerald R. Ford', 1977), ('Jimmy Carter', 1978), ('Jimmy Carter', 1979), ('Jimmy Carter', 1980), ('Ronald Reagan', 1981), ('Ronald Reagan', 1982), ('Ronald Reagan', 1983), ('Ronald Reagan', 1984), ('Ronald Reagan', 1985), ('Ronald Reagan', 1986), ('Ronald Reagan', 1987), ('Ronald Reagan', 1988), ('George Bush', 1990), ('George Bush', 1991), ('George Bush', 1992), ('George W. Bush', 2001), ('George W. Bush', 2002)]
# cluster 13
# [('James K. Polk', 1847), ('Theodore Roosevelt', 1903)]
# cluster 14
# []

# %% [markdown]
# Generally speaking, a president's speeches tend to be in the same cluster, and clusters generally contain speeches from similar time periods. However, the number of speeches per cluster is often unbalanced. Overall, these results are difficult to interpret.
